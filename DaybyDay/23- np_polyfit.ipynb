# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Topics

# %% [markdown]
# ## PolyFit

# %% [markdown]
# ### np.polyfit

# %%
X = np.arange(1, 21)
y = np.concatenate((np.arange(1,11),np.arange(10,0,-1)))

curve = np.polyfit(X, y, 2)
poly = np.poly1d(curve)

print(poly) # poly is a fn

new_X = np.arange(1, 21, 0.1)
new_y = poly(new_X)

plt.scatter(X,y)
plt.plot(new_X, new_y, color='red')
plt.show()
# Out:
#           2
# -0.09398 x + 1.974 x - 1.737

# %%
# getting the max value of y in poly 
max_y = np.max(poly(new_X))
print(max_y)
# Out:
# 8.624999999999996

# %% [markdown]
# ### polynomial regression

# %%
X = 4 * np.random.rand(50,1) - 2
Y = 4 + 2 * X + 5 * X**2 * np.random.randn(50,1)

poly_features = PolynomialFeatures(degree=5, include_bias=False)
X_poly = poly_features.fit_transform(X) # train


reg = LinearRegression()
reg.fit(X_poly,Y)
# q : why use linear regression on polynomial features
# ans : to find the best fit line for the polynomial features

X_vals = np.linspace(-2,2,100).reshape(-1,1)
X_vals_poly = poly_features.transform(X_vals)

y_vals = reg.predict(X_vals_poly)

plt.scatter(X,Y) # original data

plt.plot(X_vals,y_vals, color='red') # best fit line
plt.show()
# Out:
# 5
