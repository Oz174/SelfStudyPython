# %% [markdown]
# # Imports

# %%
import time
import random
import requests
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor , as_completed
from pprint import pprint

# %%
from pprint import pprint
import time 
import requests 
import random

def get_post(post_id: int) -> dict:
    # Value check - Posts on the API only go up to ID of 100
    if post_id > 100:
        raise ValueError("Parameter `post_id` must be less than or equal to 100")

    # API URL
    url = f"https://jsonplaceholder.typicode.com/posts/{post_id}"

    # Sleep to imitate a long-running process
    time_to_sleep = random.randint(1, 10)
    time.sleep(time_to_sleep)

    # Fetch the data and return it
    r = requests.get(url)
    r.raise_for_status()
    result = r.json()
    # To indicate how much time fetching took
    result["fetch_time"] = time_to_sleep
    # Remove the longest key-value pair for formatting reasons
    del result["body"]
    return result

pprint(get_post(1))
# Out:
# {'fetch_time': 7,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio '
#           'reprehenderit',
#  'userId': 1}

# %%
def get_post(post_id: int) -> dict:
    if post_id > 100:
        raise ValueError("Parameter `post_id` must be less than or equal to 100")

    url = f"https://jsonplaceholder.typicode.com/posts/{post_id}"

    time_to_sleep = random.randint(1, 10)
    time.sleep(time_to_sleep)

    r = requests.get(url)
    r.raise_for_status()
    result = r.json()
    result["fetch_time"] = time_to_sleep
    del result["body"]
    return result


if __name__ == "__main__":
    # Measure the time
    time_start = datetime.now()
    print("Starting to fetch posts...\n")

    # Simple iteration
    for post_id in range(1, 11):
        post = get_post(post_id)
        pprint(post)

    # Print total duration
    time_end = datetime.now()
    print(f"\nAll posts fetched! Took: {(time_end - time_start).seconds} seconds.")
# Out:
# Starting to fetch posts...
#
# {'fetch_time': 10,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio '
#           'reprehenderit',
#  'userId': 1}
# {'fetch_time': 8, 'id': 2, 'title': 'qui est esse', 'userId': 1}
# {'fetch_time': 4,
#  'id': 3,
#  'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#  'userId': 1}
# {'fetch_time': 2, 'id': 4, 'title': 'eum et est occaecati', 'userId': 1}
# {'fetch_time': 3, 'id': 5, 'title': 'nesciunt quas odio', 'userId': 1}
# {'fetch_time': 1,
#  'id': 6,
#  'title': 'dolorem eum magni eos aperiam quia',
#  'userId': 1}
# {'fetch_time': 3, 'id': 7, 'title': 'magnam facilis autem', 'userId': 1}
# {'fetch_time': 8, 'id': 8, 'title': 'dolorem dolore est ipsam', 'userId': 1}
# {'fetch_time': 1,
#  'id': 9,
#  'title': 'nesciunt iure omnis dolorem tempora et accusantium',
#  'userId': 1}
# {'fetch_time': 2, 'id': 10, 'title': 'optio molestias id quia eum', 'userId': 1}
#
# All posts fetched! Took: 48 seconds.

# %% [markdown]
# ## ThreadpoolExecuter

# %% [markdown]
# You’ll want to import ThreadPoolExecutor and the as_completed() function. The custom get_post() function remains unchanged.
#
# The real magic happens below.
#
# Essentially, you’re creating a new ThreadPoolExecutor through the context manager syntax (the most common approach). Inside, you’re using the submit() method to add tasks to the executor. The first parameter of this method is your function name, followed by its parameter values. You can dynamically iterate over a range of values for post_id using Python’s list comprehension.
#
# A Future object is returned by the submit() function.
#
# The as_completed() function will extract and print the result as individual threads finish with execution

# %%
if __name__ == "__main__":
    time_start = datetime.now()
    print("Starting to fetch posts...\n")

    # Run post fetching concurrently
    with ThreadPoolExecutor() as tpe:
        # Submit tasks and get future objects
        futures = [tpe.submit(get_post, post_id) for post_id in range(1, 11)]
        # Process task results
        for future in as_completed(futures):
            # Get and display the result
            result = future.result()
            print(result)

    time_end = datetime.now()
    print(f"\nAll posts fetched! Took: {(time_end - time_start).seconds} seconds.")
# Out:
# Starting to fetch posts...
#
# {'userId': 1, 'id': 5, 'title': 'nesciunt quas odio', 'fetch_time': 1}
# {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'fetch_time': 2}
# {'userId': 1, 'id': 2, 'title': 'qui est esse', 'fetch_time': 4}
# {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'fetch_time': 4}
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'fetch_time': 7}
# {'userId': 1, 'id': 7, 'title': 'magnam facilis autem', 'fetch_time': 8}
# {'userId': 1, 'id': 9, 'title': 'nesciunt iure omnis dolorem tempora et accusantium', 'fetch_time': 8}
# {'userId': 1, 'id': 8, 'title': 'dolorem dolore est ipsam', 'fetch_time': 9}
# {'userId': 1, 'id': 6, 'title': 'dolorem eum magni eos aperiam quia', 'fetch_time': 9}
# {'userId': 1, 'id': 10, 'title': 'optio molestias id quia eum', 'fetch_time': 10}
#
# All posts fetched! Took: 10 seconds.

# %% [markdown]
# ## Scaling things Up

# %%
if __name__ == "__main__":
    time_start = datetime.now()
    print("Starting to fetch posts...\n")

    with ThreadPoolExecutor() as tpe:
        # Submit tasks and get future objects - NOW 100 POSTS IN TOTAL
        futures = [tpe.submit(get_post, post_id) for post_id in range(1, 101)]
        for future in as_completed(futures):
            result = future.result()
            pprint(result)

    time_end = datetime.now()
    print(f"\nAll posts fetched! Took: {(time_end - time_start).seconds} seconds.")
# Out:
# Starting to fetch posts...
#
# {'fetch_time': 1,
#  'id': 12,
#  'title': 'in quibusdam tempore odit est dolorem',
#  'userId': 2}
# {'fetch_time': 2, 'id': 5, 'title': 'nesciunt quas odio', 'userId': 1}
# {'fetch_time': 4,
#  'id': 3,
#  'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#  'userId': 1}
# {'fetch_time': 5,
#  'id': 9,
#  'title': 'nesciunt iure omnis dolorem tempora et accusantium',
#  'userId': 1}
# {'fetch_time': 6, 'id': 10, 'title': 'optio molestias id quia eum', 'userId': 1}
# {'fetch_time': 7, 'id': 4, 'title': 'eum et est occaecati', 'userId': 1}
# {'fetch_time': 7, 'id': 8, 'title': 'dolorem dolore est ipsam', 'userId': 1}
# {'fetch_time': 7, 'id': 7, 'title': 'magnam facilis autem', 'userId': 1}
# {'fetch_time': 6,
#  'id': 13,
#  'title': 'dolorum ut in voluptas mollitia et saepe quo animi',
#  'userId': 2}
# {'fetch_time': 2,
#  'id': 16,
#  'title': 'sint suscipit perspiciatis velit dolorum rerum ipsa laboriosam odio',
#  'userId': 2}
# {'fetch_time': 8,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio '
#           'reprehenderit',
#  'userId': 1}
# {'fetch_time': 9, 'id': 2, 'title': 'qui est esse', 'userId': 1}
# {'fetch_time': 9,
#  'id': 6,
#  'title': 'dolorem eum magni eos aperiam quia',
#  'userId': 1}
# {'fetch_time': 5, 'id': 15, 'title': 'eveniet quod temporibus', 'userId': 2}
# {'fetch_time': 10,
#  'id': 11,
#  'title': 'et ea vero quia laudantium autem',
#  'userId': 2}
# {'fetch_time': 8, 'id': 14, 'title': 'voluptatem eligendi optio', 'userId': 2}
# {'fetch_time': 1, 'id': 26, 'title': 'est et quae odit qui non', 'userId': 3}
# {'fetch_time': 3,
#  'id': 22,
#  'title': 'dolor sint quo a velit explicabo quia nam',
#  'userId': 3}
# {'fetch_time': 2,
#  'id': 27,
#  'title': 'quasi id et eos tenetur aut quo autem',
#  'userId': 3}
# {'fetch_time': 5,
#  'id': 18,
#  'title': 'voluptate et itaque vero tempora molestiae',
#  'userId': 2}
# {'fetch_time': 6,
#  'id': 19,
#  'title': 'adipisci placeat illum aut reiciendis qui',
#  'userId': 2}
# {'fetch_time': 4,
#  'id': 25,
#  'title': 'rem alias distinctio quo quis',
#  'userId': 3}
# {'fetch_time': 6,
#  'id': 23,
#  'title': 'maxime id vitae nihil numquam',
#  'userId': 3}
# {'fetch_time': 3,
#  'id': 29,
#  'title': 'iusto eius quod necessitatibus culpa ea',
#  'userId': 3}
# {'fetch_time': 7,
#  'id': 21,
#  'title': 'asperiores ea ipsam voluptatibus modi minima quia sint',
#  'userId': 3}
# {'fetch_time': 4,
#  'id': 30,
#  'title': 'a quo magni similique perferendis',
#  'userId': 3}
# {'fetch_time': 10,
#  'id': 17,
#  'title': 'fugit voluptas sed molestias voluptatem provident',
#  'userId': 2}
# {'fetch_time': 9,
#  'id': 20,
#  'title': 'doloribus ad provident suscipit at',
#  'userId': 2}
# {'fetch_time': 7,
#  'id': 24,
#  'title': 'autem hic labore sunt dolores incidunt',
#  'userId': 3}
# {'fetch_time': 1,
#  'id': 36,
#  'title': 'fuga nam accusamus voluptas reiciendis itaque',
#  'userId': 4}
# {'fetch_time': 6,
#  'id': 28,
#  'title': 'delectus ullam et corporis nulla voluptas sequi',
#  'userId': 3}
# {'fetch_time': 2,
#  'id': 35,
#  'title': 'id nihil consequatur molestias animi provident',
#  'userId': 4}
# {'fetch_time': 4,
#  'id': 33,
#  'title': 'qui explicabo molestiae dolorem',
#  'userId': 4}
# {'fetch_time': 3,
#  'id': 37,
#  'title': 'provident vel ut sit ratione est',
#  'userId': 4}
# {'fetch_time': 5, 'id': 34, 'title': 'magnam ut rerum iure', 'userId': 4}
# {'fetch_time': 2,
#  'id': 43,
#  'title': 'eligendi iste nostrum consequuntur adipisci praesentium sit beatae '
#           'perferendis',
#  'userId': 5}
# {'fetch_time': 3,
#  'id': 39,
#  'title': 'eos dolorem iste accusantium est eaque quam',
#  'userId': 4}
# {'fetch_time': 8,
#  'id': 32,
#  'title': 'doloremque illum aliquid sunt',
#  'userId': 4}
# {'fetch_time': 4, 'id': 40, 'title': 'enim quo cumque', 'userId': 4}
# {'fetch_time': 2,
#  'id': 46,
#  'title': 'aut quo modi neque nostrum ducimus',
#  'userId': 5}
# {'fetch_time': 9,
#  'id': 31,
#  'title': 'ullam ut quidem id aut vel consequuntur',
#  'userId': 4}
# {'fetch_time': 1, 'id': 53, 'title': 'ut quo aut ducimus alias', 'userId': 6}
# {'fetch_time': 4,
#  'id': 49,
#  'title': 'laborum non sunt aut ut assumenda perspiciatis voluptas',
#  'userId': 5}
# {'fetch_time': 8,
#  'id': 45,
#  'title': 'ut numquam possimus omnis eius suscipit laudantium iure',
#  'userId': 5}
# {'fetch_time': 10,
#  'id': 38,
#  'title': 'explicabo et eos deleniti nostrum ab id repellendus',
#  'userId': 4}
# {'fetch_time': 5,
#  'id': 51,
#  'title': 'soluta aliquam aperiam consequatur illo quis voluptas',
#  'userId': 6}
# {'fetch_time': 9, 'id': 44, 'title': 'optio dolor molestias sit', 'userId': 5}
# {'fetch_time': 10,
#  'id': 42,
#  'title': 'commodi ullam sint et excepturi error explicabo praesentium '
#           'voluptas',
#  'userId': 5}
# {'fetch_time': 10, 'id': 41, 'title': 'non est facere', 'userId': 5}
# {'fetch_time': 2,
#  'id': 55,
#  'title': 'sit vel voluptatem et non libero',
#  'userId': 6}
# {'fetch_time': 6,
#  'id': 52,
#  'title': 'qui enim et consequuntur quia animi quis voluptate quibusdam',
#  'userId': 6}
# {'fetch_time': 1,
#  'id': 58,
#  'title': 'voluptatum itaque dolores nisi et quasi',
#  'userId': 6}
# {'fetch_time': 9,
#  'id': 48,
#  'title': 'ut voluptatem illum ea doloribus itaque eos',
#  'userId': 5}
# {'fetch_time': 10,
#  'id': 47,
#  'title': 'quibusdam cumque rem aut deserunt',
#  'userId': 5}
# {'fetch_time': 2,
#  'id': 61,
#  'title': 'voluptatem doloribus consectetur est ut ducimus',
#  'userId': 7}
# {'fetch_time': 1,
#  'id': 63,
#  'title': 'voluptas blanditiis repellendus animi ducimus error sapiente et '
#           'suscipit',
#  'userId': 7}
# {'fetch_time': 3,
#  'id': 56,
#  'title': 'qui et at rerum necessitatibus',
#  'userId': 6}
# {'fetch_time': 9,
#  'id': 50,
#  'title': 'repellendus qui recusandae incidunt voluptates tenetur qui omnis '
#           'exercitationem',
#  'userId': 5}
# {'fetch_time': 1,
#  'id': 64,
#  'title': 'et fugit quas eum in in aperiam quod',
#  'userId': 7}
# {'fetch_time': 5, 'id': 57, 'title': 'sed ab est est', 'userId': 6}
# {'fetch_time': 6,
#  'id': 59,
#  'title': 'qui commodi dolor at maiores et quis id accusantium',
#  'userId': 6}
# {'fetch_time': 10,
#  'id': 54,
#  'title': 'sit asperiores ipsam eveniet odio non quia',
#  'userId': 6}
# {'fetch_time': 6,
#  'id': 65,
#  'title': 'consequatur id enim sunt et et',
#  'userId': 7}
# {'fetch_time': 5,
#  'id': 68,
#  'title': 'odio quis facere architecto reiciendis optio',
#  'userId': 7}
# {'fetch_time': 9, 'id': 62, 'title': 'beatae enim quia vel', 'userId': 7}
# {'fetch_time': 1,
#  'id': 76,
#  'title': 'doloremque officiis ad et non perferendis',
#  'userId': 8}
# {'fetch_time': 4,
#  'id': 72,
#  'title': 'sint hic doloribus consequatur eos non id',
#  'userId': 8}
# {'fetch_time': 7,
#  'id': 67,
#  'title': 'aliquid eos sed fuga est maxime repellendus',
#  'userId': 7}
# {'fetch_time': 10,
#  'id': 60,
#  'title': 'consequatur placeat omnis quisquam quia reprehenderit fugit '
#           'veritatis facere',
#  'userId': 6}
# {'fetch_time': 7,
#  'id': 69,
#  'title': 'fugiat quod pariatur odit minima',
#  'userId': 7}
# {'fetch_time': 9, 'id': 66, 'title': 'repudiandae ea animi iusto', 'userId': 7}
# {'fetch_time': 3,
#  'id': 75,
#  'title': 'dignissimos eum dolor ut enim et delectus in',
#  'userId': 8}
# {'fetch_time': 1,
#  'id': 80,
#  'title': 'labore in ex et explicabo corporis aut quas',
#  'userId': 8}
# {'fetch_time': 9, 'id': 70, 'title': 'voluptatem laborum magni', 'userId': 7}
# {'fetch_time': 3,
#  'id': 81,
#  'title': 'tempora rem veritatis voluptas quo dolores vero',
#  'userId': 9}
# {'fetch_time': 10,
#  'id': 71,
#  'title': 'et iusto veniam et illum aut fuga',
#  'userId': 8}
# {'fetch_time': 5,
#  'id': 77,
#  'title': 'necessitatibus quasi exercitationem odio',
#  'userId': 8}
# {'fetch_time': 8,
#  'id': 74,
#  'title': 'enim unde ratione doloribus quas enim ut sit sapiente',
#  'userId': 8}
# {'fetch_time': 9,
#  'id': 73,
#  'title': 'consequuntur deleniti eos quia temporibus ab aliquid at',
#  'userId': 8}
# {'fetch_time': 5,
#  'id': 82,
#  'title': 'laudantium voluptate suscipit sunt enim enim',
#  'userId': 9}
# {'fetch_time': 4,
#  'id': 83,
#  'title': 'odit et voluptates doloribus alias odio et',
#  'userId': 9}
# {'fetch_time': 2, 'id': 87, 'title': 'nostrum quis quasi placeat', 'userId': 9}
# {'fetch_time': 1, 'id': 91, 'title': 'aut amet sed', 'userId': 10}
# {'fetch_time': 5,
#  'id': 85,
#  'title': 'dolore veritatis porro provident adipisci blanditiis et sunt',
#  'userId': 9}
# {'fetch_time': 5, 'id': 86, 'title': 'placeat quia et porro iste', 'userId': 9}
# {'fetch_time': 9,
#  'id': 79,
#  'title': 'pariatur consequatur quia magnam autem omnis non amet',
#  'userId': 8}
# {'fetch_time': 10,
#  'id': 78,
#  'title': 'quam voluptatibus rerum veritatis',
#  'userId': 8}
# {'fetch_time': 3,
#  'id': 96,
#  'title': 'quaerat velit veniam amet cupiditate aut numquam ut sequi',
#  'userId': 10}
# {'fetch_time': 5,
#  'id': 89,
#  'title': 'sint soluta et vel magnam aut ut sed qui',
#  'userId': 9}
# {'fetch_time': 9,
#  'id': 84,
#  'title': 'optio ipsam molestias necessitatibus occaecati facilis veritatis '
#           'dolores aut',
#  'userId': 9}
# {'fetch_time': 5,
#  'id': 92,
#  'title': 'ratione ex tenetur perferendis',
#  'userId': 10}
# {'fetch_time': 7, 'id': 88, 'title': 'sapiente omnis fugit eos', 'userId': 9}
# {'fetch_time': 5, 'id': 93, 'title': 'beatae soluta recusandae', 'userId': 10}
# {'fetch_time': 5,
#  'id': 95,
#  'title': 'id minus libero illum nam ad officiis',
#  'userId': 10}
# {'fetch_time': 2,
#  'id': 99,
#  'title': 'temporibus sit alias delectus eligendi possimus magni',
#  'userId': 10}
# {'fetch_time': 4,
#  'id': 98,
#  'title': 'laboriosam dolor voluptates',
#  'userId': 10}
# {'fetch_time': 9,
#  'id': 90,
#  'title': 'ad iusto omnis odit dolor voluptatibus',
#  'userId': 9}
# {'fetch_time': 6,
#  'id': 97,
#  'title': 'quas fugiat ut perspiciatis vero provident',
#  'userId': 10}
# {'fetch_time': 8,
#  'id': 94,
#  'title': 'qui qui voluptates illo iste minima',
#  'userId': 10}
# {'fetch_time': 4,
#  'id': 100,
#  'title': 'at nam consequatur ea labore ea harum',
#  'userId': 10}
#
# All posts fetched! Took: 54 seconds.

# %% [markdown]
# ## How to Handle Failure
# Sometimes, the function you want to run concurrently will fail. Inside the for future in as_completed(futures): block, you can add a try/except block to implement exception handling.
#
# To demonstrate, try submitting futures for post_ids up to 150 — as the get_post() function will raise an error for any post_id above 100

# %%
if __name__ == "__main__":
    time_start = datetime.now()
    print("Starting to fetch posts...\n")

    with ThreadPoolExecutor() as tpe:
        # Submit tasks and get future objects - NOW 150 POSTS IN TOTAL - 50 WILL FAIL
        futures = [tpe.submit(get_post, post_id) for post_id in range(1, 151)]
        # Process task results
        for future in as_completed(futures):
            # Your typical try/except block
            try:
                result = future.result()
                print(result)
            except Exception as e:
                print(f"Exception raised: {str(e)}")

    time_end = datetime.now()
    print(f"\nAll posts fetched! Took: {(time_end - time_start).seconds} seconds.")
# Out:
# Starting to fetch posts...
#
# {'userId': 1, 'id': 7, 'title': 'magnam facilis autem', 'fetch_time': 1}
# {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'fetch_time': 1}
# {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'fetch_time': 2}
# {'userId': 2, 'id': 11, 'title': 'et ea vero quia laudantium autem', 'fetch_time': 3}
# {'userId': 2, 'id': 13, 'title': 'dolorum ut in voluptas mollitia et saepe quo animi', 'fetch_time': 2}
# {'userId': 1, 'id': 8, 'title': 'dolorem dolore est ipsam', 'fetch_time': 4}
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'fetch_time': 4}
# {'userId': 2, 'id': 16, 'title': 'sint suscipit perspiciatis velit dolorum rerum ipsa laboriosam odio', 'fetch_time': 1}
# {'userId': 2, 'id': 14, 'title': 'voluptatem eligendi optio', 'fetch_time': 4}
# {'userId': 1, 'id': 9, 'title': 'nesciunt iure omnis dolorem tempora et accusantium', 'fetch_time': 6}
# {'userId': 1, 'id': 6, 'title': 'dolorem eum magni eos aperiam quia', 'fetch_time': 6}
# {'userId': 2, 'id': 12, 'title': 'in quibusdam tempore odit est dolorem', 'fetch_time': 7}
# {'userId': 2, 'id': 20, 'title': 'doloribus ad provident suscipit at', 'fetch_time': 2}
# {'userId': 1, 'id': 2, 'title': 'qui est esse', 'fetch_time': 8}
# {'userId': 2, 'id': 17, 'title': 'fugit voluptas sed molestias voluptatem provident', 'fetch_time': 4}
# {'userId': 2, 'id': 15, 'title': 'eveniet quod temporibus', 'fetch_time': 6}
# {'userId': 3, 'id': 22, 'title': 'dolor sint quo a velit explicabo quia nam', 'fetch_time': 3}
# {'userId': 3, 'id': 25, 'title': 'rem alias distinctio quo quis', 'fetch_time': 2}
# {'userId': 1, 'id': 5, 'title': 'nesciunt quas odio', 'fetch_time': 10}
# {'userId': 1, 'id': 10, 'title': 'optio molestias id quia eum', 'fetch_time': 10}
# {'userId': 3, 'id': 27, 'title': 'quasi id et eos tenetur aut quo autem', 'fetch_time': 2}
# {'userId': 3, 'id': 23, 'title': 'maxime id vitae nihil numquam', 'fetch_time': 5}
# {'userId': 3, 'id': 26, 'title': 'est et quae odit qui non', 'fetch_time': 3}
# {'userId': 4, 'id': 35, 'title': 'id nihil consequatur molestias animi provident', 'fetch_time': 1}
# {'userId': 2, 'id': 19, 'title': 'adipisci placeat illum aut reiciendis qui', 'fetch_time': 9}
# {'userId': 2, 'id': 18, 'title': 'voluptate et itaque vero tempora molestiae', 'fetch_time': 10}
# {'userId': 3, 'id': 21, 'title': 'asperiores ea ipsam voluptatibus modi minima quia sint', 'fetch_time': 9}
# {'userId': 3, 'id': 24, 'title': 'autem hic labore sunt dolores incidunt', 'fetch_time': 8}
# {'userId': 4, 'id': 31, 'title': 'ullam ut quidem id aut vel consequuntur', 'fetch_time': 5}
# {'userId': 4, 'id': 33, 'title': 'qui explicabo molestiae dolorem', 'fetch_time': 5}
# {'userId': 4, 'id': 39, 'title': 'eos dolorem iste accusantium est eaque quam', 'fetch_time': 1}
# {'userId': 3, 'id': 28, 'title': 'delectus ullam et corporis nulla voluptas sequi', 'fetch_time': 8}
# {'userId': 3, 'id': 30, 'title': 'a quo magni similique perferendis', 'fetch_time': 7}
# {'userId': 4, 'id': 32, 'title': 'doloremque illum aliquid sunt', 'fetch_time': 8}
# {'userId': 4, 'id': 37, 'title': 'provident vel ut sit ratione est', 'fetch_time': 5}
# {'userId': 4, 'id': 38, 'title': 'explicabo et eos deleniti nostrum ab id repellendus', 'fetch_time': 4}
# {'userId': 3, 'id': 29, 'title': 'iusto eius quod necessitatibus culpa ea', 'fetch_time': 10}
# {'userId': 4, 'id': 34, 'title': 'magnam ut rerum iure', 'fetch_time': 9}
# {'userId': 5, 'id': 49, 'title': 'laborum non sunt aut ut assumenda perspiciatis voluptas', 'fetch_time': 1}
# {'userId': 5, 'id': 46, 'title': 'aut quo modi neque nostrum ducimus', 'fetch_time': 3}
# {'userId': 4, 'id': 36, 'title': 'fuga nam accusamus voluptas reiciendis itaque', 'fetch_time': 9}
# {'userId': 5, 'id': 41, 'title': 'non est facere', 'fetch_time': 7}
# {'userId': 5, 'id': 45, 'title': 'ut numquam possimus omnis eius suscipit laudantium iure', 'fetch_time': 6}
# {'userId': 5, 'id': 44, 'title': 'optio dolor molestias sit', 'fetch_time': 7}
# {'userId': 5, 'id': 47, 'title': 'quibusdam cumque rem aut deserunt', 'fetch_time': 5}
# {'userId': 4, 'id': 40, 'title': 'enim quo cumque', 'fetch_time': 9}
# {'userId': 5, 'id': 43, 'title': 'eligendi iste nostrum consequuntur adipisci praesentium sit beatae perferendis', 'fetch_time': 8}
# {'userId': 6, 'id': 55, 'title': 'sit vel voluptatem et non libero', 'fetch_time': 1}
# {'userId': 5, 'id': 42, 'title': 'commodi ullam sint et excepturi error explicabo praesentium voluptas', 'fetch_time': 9}
# {'userId': 6, 'id': 57, 'title': 'sed ab est est', 'fetch_time': 1}
# {'userId': 5, 'id': 50, 'title': 'repellendus qui recusandae incidunt voluptates tenetur qui omnis exercitationem', 'fetch_time': 6}
# {'userId': 6, 'id': 59, 'title': 'qui commodi dolor at maiores et quis id accusantium', 'fetch_time': 2}
# {'userId': 5, 'id': 48, 'title': 'ut voluptatem illum ea doloribus itaque eos', 'fetch_time': 9}
# {'userId': 6, 'id': 51, 'title': 'soluta aliquam aperiam consequatur illo quis voluptas', 'fetch_time': 7}
# {'userId': 7, 'id': 61, 'title': 'voluptatem doloribus consectetur est ut ducimus', 'fetch_time': 3}
# {'userId': 6, 'id': 53, 'title': 'ut quo aut ducimus alias', 'fetch_time': 7}
# {'userId': 6, 'id': 54, 'title': 'sit asperiores ipsam eveniet odio non quia', 'fetch_time': 7}
# {'userId': 6, 'id': 56, 'title': 'qui et at rerum necessitatibus', 'fetch_time': 6}
# {'userId': 6, 'id': 58, 'title': 'voluptatum itaque dolores nisi et quasi', 'fetch_time': 6}
# {'userId': 7, 'id': 66, 'title': 'repudiandae ea animi iusto', 'fetch_time': 2}
# {'userId': 7, 'id': 62, 'title': 'beatae enim quia vel', 'fetch_time': 5}
# {'userId': 6, 'id': 52, 'title': 'qui enim et consequuntur quia animi quis voluptate quibusdam', 'fetch_time': 10}
# {'userId': 7, 'id': 65, 'title': 'consequatur id enim sunt et et', 'fetch_time': 4}
# {'userId': 6, 'id': 60, 'title': 'consequatur placeat omnis quisquam quia reprehenderit fugit veritatis facere', 'fetch_time': 8}
# {'userId': 7, 'id': 63, 'title': 'voluptas blanditiis repellendus animi ducimus error sapiente et suscipit', 'fetch_time': 6}
# {'userId': 8, 'id': 75, 'title': 'dignissimos eum dolor ut enim et delectus in', 'fetch_time': 1}
# {'userId': 8, 'id': 73, 'title': 'consequuntur deleniti eos quia temporibus ab aliquid at', 'fetch_time': 5}
# {'userId': 8, 'id': 71, 'title': 'et iusto veniam et illum aut fuga', 'fetch_time': 6}
# {'userId': 7, 'id': 64, 'title': 'et fugit quas eum in in aperiam quod', 'fetch_time': 10}
# {'userId': 7, 'id': 68, 'title': 'odio quis facere architecto reiciendis optio', 'fetch_time': 8}
# {'userId': 8, 'id': 76, 'title': 'doloremque officiis ad et non perferendis', 'fetch_time': 4}
# {'userId': 7, 'id': 69, 'title': 'fugiat quod pariatur odit minima', 'fetch_time': 8}
# {'userId': 8, 'id': 74, 'title': 'enim unde ratione doloribus quas enim ut sit sapiente', 'fetch_time': 7}
# {'userId': 8, 'id': 72, 'title': 'sint hic doloribus consequatur eos non id', 'fetch_time': 8}
# {'userId': 7, 'id': 70, 'title': 'voluptatem laborum magni', 'fetch_time': 9}
# {'userId': 7, 'id': 67, 'title': 'aliquid eos sed fuga est maxime repellendus', 'fetch_time': 10}
# {'userId': 9, 'id': 83, 'title': 'odit et voluptates doloribus alias odio et', 'fetch_time': 1}
# {'userId': 9, 'id': 81, 'title': 'tempora rem veritatis voluptas quo dolores vero', 'fetch_time': 2}
# {'userId': 9, 'id': 88, 'title': 'sapiente omnis fugit eos', 'fetch_time': 1}
# {'userId': 8, 'id': 79, 'title': 'pariatur consequatur quia magnam autem omnis non amet', 'fetch_time': 4}
# {'userId': 8, 'id': 77, 'title': 'necessitatibus quasi exercitationem odio', 'fetch_time': 8}
# {'userId': 9, 'id': 89, 'title': 'sint soluta et vel magnam aut ut sed qui', 'fetch_time': 2}
# {'userId': 9, 'id': 90, 'title': 'ad iusto omnis odit dolor voluptatibus', 'fetch_time': 3}
# {'userId': 9, 'id': 82, 'title': 'laudantium voluptate suscipit sunt enim enim', 'fetch_time': 6}
# {'userId': 8, 'id': 78, 'title': 'quam voluptatibus rerum veritatis', 'fetch_time': 10}
# {'userId': 10, 'id': 93, 'title': 'beatae soluta recusandae', 'fetch_time': 3}
# {'userId': 8, 'id': 80, 'title': 'labore in ex et explicabo corporis aut quas', 'fetch_time': 8}
# {'userId': 9, 'id': 85, 'title': 'dolore veritatis porro provident adipisci blanditiis et sunt', 'fetch_time': 6}
# {'userId': 10, 'id': 91, 'title': 'aut amet sed', 'fetch_time': 4}
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# Exception raised: Parameter `post_id` must be less than or equal to 100
# {'userId': 9, 'id': 84, 'title': 'optio ipsam molestias necessitatibus occaecati facilis veritatis dolores aut', 'fetch_time': 8}
# {'userId': 10, 'id': 96, 'title': 'quaerat velit veniam amet cupiditate aut numquam ut sequi', 'fetch_time': 2}
# {'userId': 10, 'id': 97, 'title': 'quas fugiat ut perspiciatis vero provident', 'fetch_time': 2}
# {'userId': 9, 'id': 86, 'title': 'placeat quia et porro iste', 'fetch_time': 8}
# {'userId': 10, 'id': 94, 'title': 'qui qui voluptates illo iste minima', 'fetch_time': 5}
# {'userId': 9, 'id': 87, 'title': 'nostrum quis quasi placeat', 'fetch_time': 9}
# {'userId': 10, 'id': 92, 'title': 'ratione ex tenetur perferendis', 'fetch_time': 8}
# {'userId': 10, 'id': 95, 'title': 'id minus libero illum nam ad officiis', 'fetch_time': 6}
# {'userId': 10, 'id': 98, 'title': 'laboriosam dolor voluptates', 'fetch_time': 5}
# {'userId': 10, 'id': 99, 'title': 'temporibus sit alias delectus eligendi possimus magni', 'fetch_time': 10}
# {'userId': 10, 'id': 100, 'title': 'at nam consequatur ea labore ea harum', 'fetch_time': 10}
#
# All posts fetched! Took: 58 seconds.

# %% [markdown]
# ## Addding Callback Functions

# %%
def future_callback_fn(future):
    print(f"[{datetime.now()}] Custom future callback function!")
    # You have access to the future object
    print(future.result())


if __name__ == "__main__":
    time_start = datetime.now()
    print("Starting to fetch posts...\n")

    with ThreadPoolExecutor() as tpe:
        futures = [tpe.submit(get_post, post_id) for post_id in range(1, 11)]
        for future in as_completed(futures):
            # Custom callback
            future.add_done_callback(future_callback_fn)

    # Print total duration
    time_end = datetime.now()
    print(f"\nAll posts fetched! Took: {(time_end - time_start).seconds} seconds.")
# Out:
# Starting to fetch posts...
#
# [2024-08-05 14:46:23.409002] Custom future callback function!
# {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'fetch_time': 1}
# [2024-08-05 14:46:24.394794] Custom future callback function!
# {'userId': 1, 'id': 7, 'title': 'magnam facilis autem', 'fetch_time': 2}
# [2024-08-05 14:46:25.353951] Custom future callback function!
# {'userId': 1, 'id': 5, 'title': 'nesciunt quas odio', 'fetch_time': 3}
# [2024-08-05 14:46:26.353645] Custom future callback function!
# {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'fetch_time': 4}
# [2024-08-05 14:46:27.413601] Custom future callback function!
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'fetch_time': 5}
# [2024-08-05 14:46:28.397078] Custom future callback function!
# {'userId': 1, 'id': 10, 'title': 'optio molestias id quia eum', 'fetch_time': 6}
# [2024-08-05 14:46:29.471027] Custom future callback function!
# {'userId': 1, 'id': 8, 'title': 'dolorem dolore est ipsam', 'fetch_time': 7}
# [2024-08-05 14:46:29.486456] Custom future callback function!
# {'userId': 1, 'id': 2, 'title': 'qui est esse', 'fetch_time': 7}
# [2024-08-05 14:46:30.445635] Custom future callback function!
# {'userId': 1, 'id': 9, 'title': 'nesciunt iure omnis dolorem tempora et accusantium', 'fetch_time': 8}
# [2024-08-05 14:46:32.353033] Custom future callback function!
# {'userId': 1, 'id': 6, 'title': 'dolorem eum magni eos aperiam quia', 'fetch_time': 10}
#
# All posts fetched! Took: 10 seconds.

# %% [markdown]
# ## Rate Limiting

# %% [markdown]
# Rate Limiting — How to Get Around That Pesky HTTP 429 Error
# Every data professional works with REST APIs. While calling their endpoints concurrently is a good way to reduce the overall runtime, it can result in aHTTP 429 Too Many Request status.
#
# The reason is simple — the API owner doesn’t want you making thousands of requests every second for the sake of performance. Or maybe, they’re restricting the traffic volume based on your subscription tear.
#
# Whatever the case might be, an easy way around it is to install the requests-ratelimiter library and limit how many requests can be made per day, hour, minute, or second

# %%
import time
import random
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
# New import
from requests_ratelimiter import LimiterSession

# Limit to max 2 calls per second
request_session = LimiterSession(per_second=2)


def get_post(post_id: int) -> dict:
    if post_id > 100:
        raise ValueError("Parameter `post_id` must be less than or equal to 100")

    url = f"https://jsonplaceholder.typicode.com/posts/{post_id}"

    time_to_sleep = random.randint(1, 10)
    time.sleep(time_to_sleep)

    # Use the request_session now
    r = request_session.get(url)
    r.raise_for_status()
    result = r.json()
    result["fetch_time"] = time_to_sleep
    del result["body"]
    return result


if __name__ == "__main__":
    time_start = datetime.now()
    print("Starting to fetch posts...\n")

    # Everything here stays the same
    with ThreadPoolExecutor() as tpe:
        futures = [tpe.submit(get_post, post_id) for post_id in range(1, 16)]
        for future in as_completed(futures):
            result = future.result()
            print(result)

    time_end = datetime.now()
    print(f"\nAll posts fetched! Took: {(time_end - time_start).seconds} seconds.")
